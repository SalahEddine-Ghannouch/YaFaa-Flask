# %%
import pandas as pd

# %%
data = pd.read_csv('Fixtures_ENG_Premier_League_elo.csv')

# %%
data.head()
# Out:
#    fixture_id fixture_referee fixture_date  venue_id  \
# 0      194200             NaN   2010-08-14       NaN
# 1      194204             NaN   2010-08-14       NaN
# 2      194201             NaN   2010-08-14       NaN
# 3      194202             NaN   2010-08-14       NaN
# 4      194199             NaN   2010-08-14       NaN
#
#                       venue_name venue_city     status_long status_short  \
# 0         The DW Stadium (Wigan)        NaN  Match Finished           FT
# 1       Stamford Bridge (London)        NaN  Match Finished           FT
# 2        Reebok Stadium (Bolton)        NaN  Match Finished           FT
# 3  Stadium of Light (Sunderland)        NaN  Match Finished           FT
# 4         Ewood Park (Blackburn)        NaN  Match Finished           FT
#
#    status_elapsed  league_id  ... goals_home goals_away score_halftime_home  \
# 0              90         39  ...          0          4                   0
# ...
